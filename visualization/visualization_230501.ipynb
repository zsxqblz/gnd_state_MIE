# %%
import numpy as np
import matplotlib.pyplot as plt
# from scipy.optimize import minimize

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### Cluster State
# parallel strings connecting A & C

# %%
plt.rcParams["figure.figsize"] = (18,5)

for i in range(1,3):
    raw = np.loadtxt("../data/230501/230501_%d_cmi.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,1)
    plt.scatter(raw[:,0],raw[:,1])
    raw = np.loadtxt("../data/230501/230501_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,2)
    plt.plot(raw[:,0],raw[:,1])
    raw = np.loadtxt("../data/230501/230501_%d_ci.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,3)
    plt.plot(raw[:,0],raw[:,1])

# xmin = 0
# plt.subplot(1,3,1)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("MIE")
# plt.subplot(1,3,2)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("MI")
# plt.subplot(1,3,3)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("CI")
# plt.tight_layout()

# %% [markdown]
# vertical strings with center cut

# %%
plt.rcParams["figure.figsize"] = (18,5)

for i in range(8,10):
    raw = np.loadtxt("../data/230501/230501_%d_cmi.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,1)
    plt.scatter(raw[:,0],raw[:,1])
    raw = np.loadtxt("../data/230501/230501_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,2)
    plt.plot(raw[:,0],raw[:,1])
    raw = np.loadtxt("../data/230501/230501_%d_ci.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,3)
    plt.plot(raw[:,0],raw[:,1])

# xmin = 0
# plt.subplot(1,3,1)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("MIE")
# plt.subplot(1,3,2)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("MI")
# plt.subplot(1,3,3)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("CI")
# plt.tight_layout()

# %% [markdown]
# Diagonal string

# %%
plt.rcParams["figure.figsize"] = (18,5)

for i in range(12,14):
    raw = np.loadtxt("../data/230501/230501_%d_cmi.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,1)
    plt.scatter(raw[:,0],raw[:,1])
    raw = np.loadtxt("../data/230501/230501_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,2)
    plt.plot(raw[:,0],raw[:,1])
    raw = np.loadtxt("../data/230501/230501_%d_ci.csv"%(i),delimiter=',',skiprows=1)
    plt.subplot(1,3,3)
    plt.plot(raw[:,0],raw[:,1])

# xmin = 0
# plt.subplot(1,3,1)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("MIE")
# plt.subplot(1,3,2)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("MI")
# plt.subplot(1,3,3)
# plt.xlim([xmin,1])
# plt.xlabel("% measurements")
# plt.ylabel("CI")
# plt.tight_layout()
