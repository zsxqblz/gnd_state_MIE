# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### Cluster State

# %% [markdown]
# I run the cluter state again because I screwed up the indexing in the previous simulations

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(16,21):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(21,26):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(26,31):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(31,35):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(36,40):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(41,46):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(46,51):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(51,56):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### Cluster state

# %% [markdown]
# A & C sites are two lines. This is more like the percolation situation

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(56,61):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(61,66):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(66,71):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(71,76):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,100])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### Toric Code

# %% [markdown]
# A & C sites are lines

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(76,81):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(81,86):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(86,91):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(91,96):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(96,101):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(101,106):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(106,111):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(111,116):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'b')
    raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'g')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(116,121):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'g')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(121,126):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'grey')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(126,131):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'grey')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(131,136):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'grey')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(136,141):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'grey')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(141,146):
    raw = np.loadtxt("data/230328/230328_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    raw = np.loadtxt("data/230328/230328_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'grey')
plt.xlim([0,200])
# plt.ylim([0,40])
# plt.yscale('log')
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
