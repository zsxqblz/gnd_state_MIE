# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### XZZX Toric Code

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(1,6):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(6,14):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(14,18):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(24,29):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(29,33):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(33,37):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(37,40):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(41,45):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(45,49):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(49,53):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(53,57):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(57,61):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(61,65):
    raw = np.loadtxt("data/230323/230323_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
# plt.xlim([0,00])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
