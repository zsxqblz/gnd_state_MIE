# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### Toric Code

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(1,9):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(9,14):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(14,19):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(19,24):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(24,29):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(29,34):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(34,39):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,raw[-1,0]])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(39,44):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(44,49):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(19,24):
    raw = np.loadtxt("data/230322/230322_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'g')

for i in range(9,13):
    raw = np.loadtxt("data/230314/230314_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'b')
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
