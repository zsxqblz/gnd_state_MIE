# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### Toric Code
# percolation but poke a hole.

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(61,66):
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')

    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'blue')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+5),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'orange')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+10),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'green')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+15),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'yellow')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+20),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(86,91):
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230410/230410_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')

    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'blue')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+5),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'orange')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+10),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'green')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+15),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'yellow')
    # raw = np.loadtxt("../data/230410/230410_%d_mi.csv"%(i+20),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
