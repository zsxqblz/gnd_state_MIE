# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %%
def guessCritPt(x_l,y_l):
    mid_pt = np.max(y_l)/2
    mid_idx = np.argmin(np.abs(y_l-mid_pt))
    return x_l[mid_idx] - y_l[mid_idx]*(x_l[mid_idx+1]-x_l[mid_idx-1])/(y_l[mid_idx+1]-y_l[mid_idx-1])

def finiteScaling(x_l,y_l,ct_pt,nu,beta,max_size):
    return (x_l-ct_pt)*(max_size**(1/nu)), y_l*(max_size**(2*beta/nu))

# %% [markdown]
# ### Toric Code
# horizontal, scale dy, scaling analysis

# %%
plt.rcParams["figure.figsize"] = (18,5)
idx_start = 200
for i in range(1,11):
    for j in range(1,2):
            id = idx_start + 10*(j-1)+i
            raw = np.load("../data/230418/230418_n%d_pp.npz"%(i+idx_start))
            n_meas_l = raw['n_meas_l']
            cmi_l = raw['cmi_l']
            mi_l = raw['mi_l']
            ci_l = raw['ci_l']
            plt.subplot(1,3,1)
            plt.plot(n_meas_l/n_meas_l[-1],cmi_l,'.-')
            plt.subplot(1,3,2)
            plt.plot(n_meas_l/n_meas_l[-1],mi_l,'.-')
            plt.subplot(1,3,3)
            plt.plot(n_meas_l/n_meas_l[-1],ci_l,'.-')

# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/frankzhang/Dropbox/Princeton/Research/Measurement-Induced Entanglement/Code/gnd_state_MIE/visualization/visualization_230418.ipynb Cell 5 in <module>
#       <a href='vscode-notebook-cell:/Users/frankzhang/Dropbox/Princeton/Research/Measurement-Induced%20Entanglement/Code/gnd_state_MIE/visualization/visualization_230418.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> for j in range(1,2):
#       <a href='vscode-notebook-cell:/Users/frankzhang/Dropbox/Princeton/Research/Measurement-Induced%20Entanglement/Code/gnd_state_MIE/visualization/visualization_230418.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>         id = idx_start + 10*(j-1)+i
# ----> <a href='vscode-notebook-cell:/Users/frankzhang/Dropbox/Princeton/Research/Measurement-Induced%20Entanglement/Code/gnd_state_MIE/visualization/visualization_230418.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>         raw = np.load("../data/230418/230418_n%d_pp.npz"%(i+idx_start))
#       <a href='vscode-notebook-cell:/Users/frankzhang/Dropbox/Princeton/Research/Measurement-Induced%20Entanglement/Code/gnd_state_MIE/visualization/visualization_230418.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>         n_meas_l = raw['n_meas_l']
#       <a href='vscode-notebook-cell:/Users/frankzhang/Dropbox/Princeton/Research/Measurement-Induced%20Entanglement/Code/gnd_state_MIE/visualization/visualization_230418.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>         cmi_l = raw['cmi_l']
#
# File /usr/local/lib/python3.9/site-packages/numpy/lib/npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/230418/230418_n201_pp.npz'

# %% [markdown]
# ### Toric Code
# scaling analysis with Della data

# %%
plt.rcParams["figure.figsize"] = (18,5)
idx_start = 20
size_l = [20,40,60,80,100]
for i in range(1,6):
# for i in [1,2,4]:
    raw = np.load("../data/230418/230418_n%d_pp.npz"%(i+idx_start))
    n_meas_l = raw['n_meas_l']
    cmi_l = raw['cmi_l']
    mi_l = raw['mi_l']
    ci_l = raw['ci_l']
    plt.subplot(1,3,1)
    # plt.plot(n_meas_l/size_l[i-1],cmi_l,'.-')
    plt.plot(n_meas_l/n_meas_l[-1],cmi_l,'.-')
    plt.subplot(1,3,2)
    # plt.plot(n_meas_l/size_l[i-1],mi_l,'.-')
    plt.plot(n_meas_l/n_meas_l[-1],mi_l,'.-')
    plt.subplot(1,3,3)
    # plt.plot(n_meas_l/size_l[i-1],ci_l,'.-')
    plt.plot(n_meas_l/n_meas_l[-1],ci_l,'.-')

# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
idx_start = 20

raw = np.load("../data/230418/230418_n%d_pp.npz"%(5+idx_start))
n_meas_l = raw['n_meas_l']
max_meas = n_meas_l[-1]
n_meas_l = n_meas_l/max_meas
cmi_l = raw['cmi_l']

beta_i = 0.536
nu_i = 0.733
ct_pt_i = guessCritPt(n_meas_l,cmi_l)
print(ct_pt_i)

for i in range(1,6):
    raw = np.load("../data/230418/230418_n%d_pp.npz"%(i+idx_start))
    n_meas_l = raw['n_meas_l']
    max_meas = n_meas_l[-1]
    n_meas_l = n_meas_l/max_meas
    cmi_l = raw['cmi_l']
    scaled_meas, scaled_cmi = finiteScaling(n_meas_l,cmi_l,ct_pt_i,nu_i,beta_i,max_meas)
    plt.plot(scaled_meas,scaled_cmi,'.-')

    interp_meas = np.arange(-1000,1000,50)
    interp_cmi = np.interp(interp_meas,scaled_meas,scaled_cmi)
    # plt.plot(interp_meas,interp_cmi,'.-')

plt.xlim([-1000,1000])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
# Out:
# 0.910485279706873

# %%
def finiteScalingCost(param,x_arr,y_arr,max_size_l,interp_x):
    ct_pt = param[0]
    nu = param[1]
    beta = param[2]
    
    n_exp = x_arr.shape[0]
    x_len = x_arr.shape[1]

    target_x, target_y = finiteScaling(x_arr[-1,:],y_arr[-1,:],ct_pt,nu,beta,max_size_l[-1])
    interp_target_y = np.interp(interp_x,target_x,target_y)
    
    cost = 0
    for i in range(n_exp):
        scaled_x, scaled_y = finiteScaling(x_arr[i,:],y_arr[i,:],ct_pt,nu,beta,max_size_l[i])
        interp_y = np.interp(interp_x,scaled_x,scaled_y)
        cost = cost + np.norm(interp_target_y-interp_y)
    
    return cost

# %%
idx_start = 20
for i in range(1,6):
    raw = np.load("../data/230418/230418_n%d_pp.npz"%(i+idx_start))
    n_meas_l = raw['n_meas_l']
    max_meas = n_meas_l[-1]
    n_meas_l = n_meas_l/max_meas
    cmi_l = raw['cmi_l']
    scaled_meas, scaled_cmi = finiteScaling(n_meas_l,cmi_l,ct_pt_i,nu_i,beta_i,max_meas)
    # plt.plot(scaled_meas,scaled_cmi,'.-')

    interp_meas = np.linspace(-1000,1000,100)
    # interp_cmi = np.interp(interp_meas,n_meas_l,cmi_l)

    if i == 1:
        n_meas_arr = n_meas_l
        cmi_arr = cmi_l
        max_meas_l = np.array([max_meas])
    else:
        n_meas_arr = np.vstack((n_meas_arr,n_meas_l))
        cmi_arr = np.vstack((n_meas_arr,cmi_l))
        max_meas_l = np.append(max_meas_l,max_meas)

print(max_meas_l)
# Out:
# [180. 380. 580. 780. 980.]
