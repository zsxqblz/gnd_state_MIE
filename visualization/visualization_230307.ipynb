# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### Toric Code

# %%
raw = np.loadtxt("data/230307/230307_%d.csv"%(1),delimiter=',',skiprows=1)
plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
# Out:
# Text(0, 0.5, 'MIE')

# %%
raw = np.loadtxt("data/230307/230307_%d.csv"%(2),delimiter=',',skiprows=1)
plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
# Out:
# Text(0, 0.5, 'MIE')

# %%
plt.rcParams["figure.figsize"] = (6,5)
raw = np.loadtxt("data/230307/230307_%d.csv"%(1),delimiter=',',skiprows=1)
plt.plot(raw[:,0],raw[:,1])
raw = np.loadtxt("data/230307/230307_%d.csv"%(3),delimiter=',',skiprows=1)
plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
raw = np.loadtxt("data/230314/230314_%d.csv"%(1),delimiter=',',skiprows=1)
plt.plot(raw[:,0],raw[:,1])
raw = np.loadtxt("data/230314/230314_%d.csv"%(2),delimiter=',',skiprows=1)
plt.plot(raw[:,0],raw[:,1])
plt.xlim([0,200])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
