# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 20})
plt.rcParams.update({'lines.linewidth': 2})

# %% [markdown]
# ### Toric Code
# A & C are along diagonal. Hope to see behavior "stronger" than percolation

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(1,6):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(6,11):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(11,16):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(16,21):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(21,26):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(26,31):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### Toric Code
# percolation but poke holes. horizontal or diagonal

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(11,16):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(31,36):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### Cluster State
# percoluation but poke holes

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(56,61):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'purple')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+25),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(86,91):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'purple')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+25),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(116,121):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'purple')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+25),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### XZZX Toric Code
# percoluation but poke holes

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(146,151):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'purple')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+25),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')

    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'blue')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+5),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'orange')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+10),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'green')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+15),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'yellow')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+20),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'purple')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+25),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(177,180):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'purple')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+25),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')

    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'blue')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+5),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'orange')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+10),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'green')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+15),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'yellow')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+20),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'purple')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+25),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(207,210):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'blue')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+5),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'orange')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+10),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'green')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+15),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'yellow')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+20),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'purple')
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i+25),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1],'red')

    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'blue')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+5),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'orange')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+10),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'green')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+15),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'yellow')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+20),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'purple')
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i+25),delimiter=',',skiprows=1)
    # plt.plot(raw[:,0],raw[:,1],'red')
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### XZZX Toric Code
# take diagonal lines

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(236,241):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(241,246):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(246,251):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %% [markdown]
# ### Cluster State
# diagonal line

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(251,256):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(256,261):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(261,266):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(266,274):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()

# %%
plt.rcParams["figure.figsize"] = (6,5)
for i in range(274,281):
    raw = np.loadtxt("../data/230405/230405_%d.csv"%(i),delimiter=',',skiprows=1)
    plt.plot(raw[:,0],raw[:,1])
    # raw = np.loadtxt("../data/230405/230405_%d_mi.csv"%(i),delimiter=',',skiprows=1)
    # plt.scatter(raw[:,0],raw[:,1])
# plt.xlim([0,100])
plt.xlabel("# measurements")
plt.ylabel("MIE")
plt.tight_layout()
